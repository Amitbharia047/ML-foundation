# %%
print("Hello World")
# Out:
# Hello World

# %%
print("" \
"")

# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np

# %%
arr = np.array([])
print(arr)
# Out:
# []

# %%
type(arr) #dimensional array
# Out:
# numpy.ndarray

# %%
arr1 = np.array([1,2,3,4,5])

# %%
print("Dimension:",arr1.ndim)
print("Number of elements:",arr1.size)
print("The data type of the array:",arr1.dtype)
# Out:
# Dimension: 1
# Number of elements: 5
# The data type of the array: int64

# %% [markdown]
# 2-D array

# %%
array2d = np.array([[],[],[]])
array2d = np.array([[1,2],[3,4]])
print(array2d)
print(type(array2d))
print(array2d.ndim)
# Out:
# [[1 2]
#  [3 4]]
# <class 'numpy.ndarray'>
# 2
